# %% [markdown]
# - Arquivo .csv é criado

# %%
import pandas as pd

Boletim={'nome': ['Pedro', '', 'João', 'Tiago', 'Mara', 'Estér', 'Gabriel', 'Débora', '', 'André', 'Aila', 'Gabriela', 'Junior', '', ''],
         'matemática': [10, '', 9.1, 3.5, 4, 6, 7.8, 5.4, '', 10, 9.9, 3.2, 2.1, '', ''],
         'português': [5.4, '', 3.2, 1, 10, 9.5, 10, 1.3, '', 9.8, 10, 7.4, 9, '', ''],
         'geografia': [10, '', 7.3, 0.5, 5.9, 8.3, 8, 9.4, '', 4, 10, 8.9, 10, '', '']}

df=pd.DataFrame(Boletim)

# %% [markdown]
# - Métodos de visualização

# %%
df.head(3)
# Out:
#     nome matemática português geografia
# 0  Pedro         10       5.4        10
# 1
# 2   João        9.1       3.2       7.3

# %%
df.tail(4)
# Out:
#         nome matemática português geografia
# 11  Gabriela        3.2       7.4       8.9
# 12    Junior        2.1         9        10
# 13
# 14

# %%
df.iloc[5:6]
# Out:
#     nome matemática português geografia
# 5  Estér          6       9.5       8.3

# %%
df.loc[(df['nome']=='Gabriela')]
# Out:
#         nome matemática português geografia
# 11  Gabriela        3.2       7.4       8.9

# %% [markdown]
# - Métodos de ordenação

# %%
df.sort_values(by=['nome'])
# Out:
#         nome matemática português geografia
# 1
# 8
# 13
# 14
# 10      Aila        9.9        10        10
# 9      André         10       9.8         4
# 7     Débora        5.4       1.3       9.4
# 5      Estér          6       9.5       8.3
# 6    Gabriel        7.8        10         8
# 11  Gabriela        3.2       7.4       8.9
# 2       João        9.1       3.2       7.3
# 12    Junior        2.1         9        10
# 4       Mara          4        10       5.9
# 0      Pedro         10       5.4        10
# 3      Tiago        3.5         1       0.5

# %%
df.isnull()
# Out:
#      nome  matemática  português  geografia
# 0   False       False      False      False
# 1   False       False      False      False
# 2   False       False      False      False
# 3   False       False      False      False
# 4   False       False      False      False
# 5   False       False      False      False
# 6   False       False      False      False
# 7   False       False      False      False
# 8   False       False      False      False
# 9   False       False      False      False
# 10  False       False      False      False
# 11  False       False      False      False
# 12  False       False      False      False
# 13  False       False      False      False
# 14  False       False      False      False

# %% [markdown]
# - Métodos de descrição

# %%
df.describe()
# Out:
#        nome matemática português geografia
# count    15         15        15        15
# unique   12         11        10        10
# top
# freq      4          4         4         4

# %%
df.shape
# Out:
# (15, 4)

# %%
df.dtypes
# Out:
# nome          object
# matemática    object
# português     object
# geografia     object
# dtype: object
